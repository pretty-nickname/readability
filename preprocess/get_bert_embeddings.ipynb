# %%
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('distiluse-base-multilingual-cased')
#model = SentenceTransformer('all-mpnet-base-v2')
# Out:
# ...
#      |████████████████████████████████| 78 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 11.9 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 47.0 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 49.4 MB/s
# ...
#      |████████████████████████████████| 56 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 65.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 58.0 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.1.0-py3-none-any.whl size=121000 sha256=ccdd55ea5d99ff95f2a031dadf99a67c368e76daee3e7ba90b64205892577ff4
#   Stored in directory: /root/.cache/pip/wheels/90/f0/bb/ed1add84da70092ea526466eadc2bfb197c4bcb8d4fa5f7bad
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=False)

# %% [markdown]
# #read corpora

# %%
#fiction read

import pandas as pd
csv_path = ""
df1 = pd.read_csv(csv_path)
test_texts = list(df1.text.values)
csv_path = ""
df1 = pd.read_csv(csv_path)
train_texts = list(df1.text.values)

# %%
# kaggle

import pandas as pd

csv_path = ""
df = pd.read_csv(csv_path)
train_texts = list(df.excerpt.values)

csv_path = ""
df = pd.read_csv(csv_path)
test_texts = list(df.excerpt.values)

# %%
# common core

path = '/content/gdrive/MyDrive/fiction_previews/common core/eng_corpus/'
import pandas as pd

csv_path = ""
df = pd.read_csv(csv_path)
files = list(df.File.values)

train_texts = []
for f in files:
  with open(path + f) as f1:
      content = f1.read()
  #content = clean_text_eng(content)
  train_texts.append(content)

# %%
# fiction_recommended

import pandas as pd
import os
import zipfile
zip_path = ""
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/1")

files = os.listdir("/content/1/fragments/train")
path = ""
df = pd.read_csv(path, header = None)

path = "/content/1/fragments/train/"

train_texts = []

for i, f in enumerate(files):
  if i%1000 == 0:
    print(i)
  with open(path + f) as f1:
      content = f1.read()
  train_texts.append(content)
###############
files = os.listdir("/content/1/fragments/test")
path = ""
df = pd.read_csv(path, header = None)

path = "/content/1/fragments/test/"

test_texts = []

for i, f in enumerate(files):
  if i%1000 == 0:
    print(i)
  with open(path + f) as f1:
      content = f1.read()
  test_texts.append(content)

from collections import Counter
Counter(train_labels)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 0
# 1000
# Counter({0: 1289, 1: 2105, 2: 4651})

# %%
#OneStopEnglish

import pandas as pd
csv_path = ""
df = pd.read_csv(csv_path)
train_texts = list(df.texts.values)
df.head()
# Out:
#                  file_name  ... labels
# 0  climate change -int.txt  ...      1
# 1     Crowdfunding-int.txt  ...      1
# 2   WNL Can the US-ele.txt  ...      0
# 3     WNL Tributes-int.txt  ...      1
# 4  WNL New Orleans-int.txt  ...      1
#
# [5 rows x 3 columns]

# %% [markdown]
# #get embs

# %%
import pickle
sentence_embeddings = model.encode(train_texts)  
with open('/content/gdrive/MyDrive/fiction_previews/sent_trans_kaggle_train.pickle', 'wb') as f:
        pickle.dump(sentence_embeddings, f) 

sentence_embeddings = model.encode(test_texts)  
with open('/content/gdrive/MyDrive/fiction_previews/sent_trans_kaggle_test.pickle', 'wb') as f:
        pickle.dump(sentence_embeddings, f)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2227: UserWarning: `max_length` is ignored when `padding`=`True`.
#   warnings.warn("`max_length` is ignored when `padding`=`True`.")
